# %%
import numpy as np

# %%
# Out:
# np.int64(4)

# %%
a = np.array([23, 78, 45, 12, 89, 34, 67, 90, 11, 56], np.int8)
a.argmin()
# Out:
# np.int64(8)

# %%
a.argmax()
# Out:
# np.int64(7)

# %%
b = np.array([5, 99, 32, 74, 18, 61, 47, 83, 26, 10], np.int8)
b.argmin()
# Out:
# np.int64(0)

# %%
b.argmax()
# Out:
# np.int64(1)

# %%
c = np.array([88, 14, 39, 72, 6, 55, 91, 27, 63, 40])
c.argmin()
# Out:
# np.int64(4)

# %%
c.argmax()
# Out:
# np.int64(6)

# %%
d = np.array([19, 81, 33, 52, 7, 95, 24, 68, 44, 13])
d.argmin()
# Out:
# np.int64(4)

# %%
d.argmax()
# Out:
# np.int64(5)

# %%
e = np.array([62, 17, 76, 38, 93, 1, 54, 69, 43, 80])
e.argmin()
# Out:
# np.int64(4)

# %%
e.argmax()
# Out:
# np.int64(4)

# %%
# 2d array

f = np.array([[
    [1, 7, 3, 0, 9],
   [4, 2, 8, 5, 6],
   [9, 1, 0, 3, 7],
   [6, 8, 2, 4, 5],
   [3, 0, 7, 9, 1]
              ]])
print(f)
f.shape
# Out:
# [[[1 7 3 0 9]
#   [4 2 8 5 6]
#   [9 1 0 3 7]
#   [6 8 2 4 5]
#   [3 0 7 9 1]]]
# np.int64(4)

# %%
g = np.array([[
    [0, 4, 7, 2, 8],
  [9, 1, 5, 6, 3],
  [2, 8, 0, 4, 7],
  [6, 3, 9, 1, 5],
  [7, 5, 2, 8, 0]

    
]])
print(g)
g.shape
# Out:
# [[[0 4 7 2 8]
#   [9 1 5 6 3]
#   [2 8 0 4 7]
#   [6 3 9 1 5]
#   [7 5 2 8 0]]]
# (1, 5, 5)

# %%
h = np.array([[[2, 5, 8, 1, 6],
  [7, 3, 0, 9, 4],
  [1, 6, 2, 8, 5],
  [9, 4, 7, 3, 0],
  [8, 0, 5, 2, 1]]])
print(h)
h.shape
# Out:
# [[[2 5 8 1 6]
#   [7 3 0 9 4]
#   [1 6 2 8 5]
#   [9 4 7 3 0]
#   [8 0 5 2 1]]]
# (1, 5, 5)

# %%
i = np.array([[
    [9, 2, 4, 7, 1],
  [3, 8, 5, 0, 6],
  [7, 1, 9, 2, 4],
  [0, 6, 3, 8, 5],
  [5, 4, 1, 9, 2]
]])
print(i)
i.shape
# Out:
# [[[9 2 4 7 1]
#   [3 8 5 0 6]
#   [7 1 9 2 4]
#   [0 6 3 8 5]
#   [5 4 1 9 2]]]
# (1, 5, 5)

# %%
j = np.array([[
    
  [6, 0, 3, 8, 2],
  [1, 9, 4, 7, 5],
  [8, 2, 6, 1, 3],
  [5, 7, 0, 4, 9],
  [2, 3, 8, 6, 1]

]])
print(j)
j.shape
# Out:
# [[[6 0 3 8 2]
#   [1 9 4 7 5]
#   [8 2 6 1 3]
#   [5 7 0 4 9]
#   [2 3 8 6 1]]]
# (1, 5, 5)

# %%
k = np.array([[

    [5, 8, 2, 4, 7],
  [1, 3, 9, 0, 6],
  [7, 2, 5, 8, 4],
  [0, 6, 1, 3, 9],
  [4, 9, 7, 2, 5]


]])
print(k)
k.shape
# Out:
# [[[5 8 2 4 7]
#   [1 3 9 0 6]
#   [7 2 5 8 4]
#   [0 6 1 3 9]
#   [4 9 7 2 5]]]
# (1, 5, 5)

# %%
l = np.array([[
    [7, 1, 6, 3, 0],
  [2, 9, 4, 8, 5],
  [0, 3, 7, 1, 6],
  [5, 8, 2, 9, 4],
  [6, 4, 0, 7, 1]

]])
print(l)
l.shape
# Out:
# [[[7 1 6 3 0]
#   [2 9 4 8 5]
#   [0 3 7 1 6]
#   [5 8 2 9 4]
#   [6 4 0 7 1]]]
# (1, 5, 5)

# %%
m = np.array([[

    [8, 3, 5, 1, 9],
  [4, 7, 0, 6, 2],
  [9, 1, 8, 3, 5],
  [6, 2, 4, 7, 0],
  [5, 0, 9, 8, 3]
]])
print(m)
m.shape
# Out:
# [[[8 3 5 1 9]
#   [4 7 0 6 2]
#   [9 1 8 3 5]
#   [6 2 4 7 0]
#   [5 0 9 8 3]]]
# (1, 5, 5)

# %%
n = np.array([[

    [2, 7, 0, 5, 8],
  [6, 1, 3, 9, 4],
  [8, 5, 2, 7, 0],
  [9, 4, 6, 1, 3],
  [0, 3, 8, 2, 7]

]])
print(n)
n.shape
# Out:
# [[[2 7 0 5 8]
#   [6 1 3 9 4]
#   [8 5 2 7 0]
#   [9 4 6 1 3]
#   [0 3 8 2 7]]]
# (1, 5, 5)

# %%
o = np.array([[
    [1, 7, 3, 0, 9],
  [4, 2, 8, 5, 6],
  [9, 1, 0, 3, 7],
  [6, 8, 2, 4, 5],
  [3, 0, 7, 9, 1]

]])
print(o)
o.shape
# Out:
# [[[1 7 3 0 9]
#   [4 2 8 5 6]
#   [9 1 0 3 7]
#   [6 8 2 4 5]
#   [3 0 7 9 1]]]
# (1, 5, 5)

# %%
# 3d array
p = np.array([ [[9, 1, 0, 3, 7],
  [6, 8, 2, 4, 5],
  [3, 0, 7, 9, 1]], [[4, 2, 8, 5, 6],
  [9, 1, 0, 3, 7],
  [6, 8, 2, 4, 5]], [ [9, 1, 0, 3, 7],
  [6, 8, 2, 4, 5],
  [3, 0, 7, 9, 1]
],[[6, 1, 3, 9, 4],
  [8, 5, 2, 7, 0],
  [9, 4, 6, 1, 3]] ])
print(p)
p.shape
# Out:
# [[[9 1 0 3 7]
#   [6 8 2 4 5]
#   [3 0 7 9 1]]
#
#  [[4 2 8 5 6]
#   [9 1 0 3 7]
#   [6 8 2 4 5]]
#
#  [[9 1 0 3 7]
#   [6 8 2 4 5]
#   [3 0 7 9 1]]
#
#  [[6 1 3 9 4]
#   [8 5 2 7 0]
#   [9 4 6 1 3]]]
# (4, 3, 5)

# %%
q = np.array([ [
  [0, 1, 2, 3],
  [1, 2, 3, 0],
  [2, 3, 0, 1],
  [3, 0, 1, 2]
], [
  [4, 5, 6, 7],
  [5, 6, 7, 4],
  [6, 7, 4, 5],
  [7, 4, 5, 6]
], [
  [0, 2, 4, 6],
  [2, 4, 6, 0],
  [4, 6, 0, 2],
  [6, 0, 2, 4]
],[
  [9, 8, 7, 6],
  [8, 7, 6, 9],
  [7, 6, 9, 8],
  [6, 9, 8, 7]
]])
print(p)
p.shape
# Out:
# [[[9 1 0 3 7]
#   [6 8 2 4 5]
#   [3 0 7 9 1]]
#
#  [[4 2 8 5 6]
#   [9 1 0 3 7]
#   [6 8 2 4 5]]
#
#  [[9 1 0 3 7]
#   [6 8 2 4 5]
#   [3 0 7 9 1]]
#
#  [[6 1 3 9 4]
#   [8 5 2 7 0]
#   [9 4 6 1 3]]]
# (4, 3, 5)

# %%
r = np.array([[
  [8, 0, 3, 5],
  [0, 3, 5, 8],
  [3, 5, 8, 0],
  [5, 8, 0, 3]
],[
  [2, 9, 4, 7],
  [9, 4, 7, 2],
  [4, 7, 2, 9],
  [7, 2, 9, 4]
],[
  [4, 1, 7, 3],
  [1, 7, 3, 4],
  [7, 3, 4, 1],
  [3, 4, 1, 7]
],[
  [3, 6, 9, 2],
  [6, 9, 2, 3],
  [9, 2, 3, 6],
  [2, 3, 6, 9]
]])
print(r)
r.shape
# Out:
# [[[8 0 3 5]
#   [0 3 5 8]
#   [3 5 8 0]
#   [5 8 0 3]]
#
#  [[2 9 4 7]
#   [9 4 7 2]
#   [4 7 2 9]
#   [7 2 9 4]]
#
#  [[4 1 7 3]
#   [1 7 3 4]
#   [7 3 4 1]
#   [3 4 1 7]]
#
#  [[3 6 9 2]
#   [6 9 2 3]
#   [9 2 3 6]
#   [2 3 6 9]]]
# (4, 4, 4)

# %%
s = np.array([[
  [3, 6, 9, 2],
  [6, 9, 2, 3],
  [9, 2, 3, 6],
  [2, 3, 6, 9]
],[
  [3, 6, 9, 2],
  [6, 9, 2, 3],
  [9, 2, 3, 6],
  [2, 3, 6, 9]
],[
  [3, 6, 9, 2],
  [6, 9, 2, 3],
  [9, 2, 3, 6],
  [2, 3, 6, 9]
],[
  [3, 6, 9, 2],
  [6, 9, 2, 3],
  [9, 2, 3, 6],
  [2, 3, 6, 9]
]])
print(s)
s.shape
# Out:
# [[[3 6 9 2]
#   [6 9 2 3]
#   [9 2 3 6]
#   [2 3 6 9]]
#
#  [[3 6 9 2]
#   [6 9 2 3]
#   [9 2 3 6]
#   [2 3 6 9]]
#
#  [[3 6 9 2]
#   [6 9 2 3]
#   [9 2 3 6]
#   [2 3 6 9]]
#
#  [[3 6 9 2]
#   [6 9 2 3]
#   [9 2 3 6]
#   [2 3 6 9]]]
# (4, 4, 4)

# %%
t = np.array([[
  [0, 5, 1, 6],
  [5, 1, 6, 0],
  [1, 6, 0, 5],
  [6, 0, 5, 1]
],[
  [3, 6, 9, 2],
  [6, 9, 2, 3],
  [9, 2, 3, 6],
  [2, 3, 6, 9]
],[
  [9, 8, 7, 6],
  [8, 7, 6, 9],
  [7, 6, 9, 8],
  [6, 9, 8, 7]
],[
  [0, 1, 2, 3],
  [1, 2, 3, 0],
  [2, 3, 0, 1],
  [3, 0, 1, 2]
]])
print(t)
t.shape
# Out:
# [[[0 5 1 6]
#   [5 1 6 0]
#   [1 6 0 5]
#   [6 0 5 1]]
#
#  [[3 6 9 2]
#   [6 9 2 3]
#   [9 2 3 6]
#   [2 3 6 9]]
#
#  [[9 8 7 6]
#   [8 7 6 9]
#   [7 6 9 8]
#   [6 9 8 7]]
#
#  [[0 1 2 3]
#   [1 2 3 0]
#   [2 3 0 1]
#   [3 0 1 2]]]
# (4, 4, 4)

# %%
u = np.array([[[0, 1, 2, 3],
  [1, 2, 3, 0],
  [2, 3, 0, 1],
  [3, 0, 1, 2]
], [
  [4, 5, 6, 7],
  [5, 6, 7, 4],
  [6, 7, 4, 5],
  [7, 4, 5, 6]
], [
  [0, 2, 4, 6],
  [2, 4, 6, 0],
  [4, 6, 0, 2],
  [6, 0, 2, 4]
],[
  [9, 8, 7, 6],
  [8, 7, 6, 9],
  [7, 6, 9, 8],
  [6, 9, 8, 7]]])
print(u)
u.shape
# Out:
# [[[0 1 2 3]
#   [1 2 3 0]
#   [2 3 0 1]
#   [3 0 1 2]]
#
#  [[4 5 6 7]
#   [5 6 7 4]
#   [6 7 4 5]
#   [7 4 5 6]]
#
#  [[0 2 4 6]
#   [2 4 6 0]
#   [4 6 0 2]
#   [6 0 2 4]]
#
#  [[9 8 7 6]
#   [8 7 6 9]
#   [7 6 9 8]
#   [6 9 8 7]]]
# (4, 4, 4)

# %%
v = np.array([[[4, 5, 6, 7],
  [5, 6, 7, 4],
  [6, 7, 4, 5],
  [7, 4, 5, 6]
], [
  [0, 2, 4, 6],
  [2, 4, 6, 0],
  [4, 6, 0, 2],
  [6, 0, 2, 4]
],[
  [9, 8, 7, 6],
  [8, 7, 6, 9],
  [7, 6, 9, 8]
]])
print(v)
v.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 v = np.array([[[4, 5, 6, 7],
#       2   [5, 6, 7, 4],
#       3   [6, 7, 4, 5],
#       4   [7, 4, 5, 6]
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.

# %%
w = np.array([[
  [0, 5, 1, 6],
  [5, 1, 6, 0],
  [1, 6, 0, 5],
  [6, 0, 5, 1]
],[[4, 5, 6, 7],
  [5, 6, 7, 4],
  [6, 7, 4, 5],
  [7, 4, 5, 6]
], [
  [0, 2, 4, 6],
  [2, 4, 6, 0],
  [4, 6, 0, 2],
  [6, 0, 2, 4]
]])
print(w)
w.shape
# Out:
# [[[0 5 1 6]
#   [5 1 6 0]
#   [1 6 0 5]
#   [6 0 5 1]]
#
#  [[4 5 6 7]
#   [5 6 7 4]
#   [6 7 4 5]
#   [7 4 5 6]]
#
#  [[0 2 4 6]
#   [2 4 6 0]
#   [4 6 0 2]
#   [6 0 2 4]]]
# (3, 4, 4)

# %%
x = np.array([[[6, 0, 3, 8, 2],
  [1, 9, 4, 7, 5],
  [8, 2, 6, 1, 3],
  [5, 7, 0, 4, 9],
  [2, 3, 8, 6, 1]
],[[6, 0, 3, 8, 2],
  [1, 9, 4, 7, 5],
  [8, 2, 6, 1, 3],
  [5, 7, 0, 4, 9],
  [2, 3, 8, 6, 1]
  ],[[6, 0, 3, 8, 2],
  [1, 9, 4, 7, 5],
  [8, 2, 6, 1, 3],
  [5, 7, 0, 4, 9],
  [2, 3, 8, 6, 1]
    ]])
print(x)
x.shape
# Out:
# [[[6 0 3 8 2]
#   [1 9 4 7 5]
#   [8 2 6 1 3]
#   [5 7 0 4 9]
#   [2 3 8 6 1]]
#
#  [[6 0 3 8 2]
#   [1 9 4 7 5]
#   [8 2 6 1 3]
#   [5 7 0 4 9]
#   [2 3 8 6 1]]
#
#  [[6 0 3 8 2]
#   [1 9 4 7 5]
#   [8 2 6 1 3]
#   [5 7 0 4 9]
#   [2 3 8 6 1]]]
# (3, 5, 5)

# %%
y = np.array([[[2, 5, 8, 1, 6],
  [7, 3, 0, 9, 4],
  [1, 6, 2, 8, 5],
  [9, 4, 7, 3, 0],
  [8, 0, 5, 2, 1]], [[2, 5, 8, 1, 6],
  [7, 3, 0, 9, 4],
  [1, 6, 2, 8, 5],
  [9, 4, 7, 3, 0],
  [8, 0, 5, 2, 1]],[[2, 5, 8, 1, 6],
  [7, 3, 0, 9, 4],
  [1, 6, 2, 8, 5],
  [9, 4, 7, 3, 0],
  [8, 0, 5, 2, 1]]])
print(y)
y.shape
# Out:
# [[[2 5 8 1 6]
#   [7 3 0 9 4]
#   [1 6 2 8 5]
#   [9 4 7 3 0]
#   [8 0 5 2 1]]
#
#  [[2 5 8 1 6]
#   [7 3 0 9 4]
#   [1 6 2 8 5]
#   [9 4 7 3 0]
#   [8 0 5 2 1]]
#
#  [[2 5 8 1 6]
#   [7 3 0 9 4]
#   [1 6 2 8 5]
#   [9 4 7 3 0]
#   [8 0 5 2 1]]]
# (3, 5, 5)

# %%
z = np.array([[
  [0, 1, 2],
  [1, 2, 0],
  [2, 0, 1]
],[
  [3, 4, 5],
  [4, 5, 3],
  [5, 3, 4]
],)
print(s)
z.shape
